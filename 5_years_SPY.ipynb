# %%
import pandas as pd
import yfinance as yf


spy_ticker = yf.Ticker("SPY")
spy_data = spy_ticker.history(period="5y")

print(spy_data.head(5))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00  350.343062  350.473762  340.550903  344.256805
# 2021-01-05 00:00:00-05:00  343.612636  347.719926  343.565945  346.627747
# 2021-01-06 00:00:00-05:00  345.115588  351.901980  344.564840  348.700134
# 2021-01-07 00:00:00-05:00  351.080521  354.627721  350.903159  353.880951
# 2021-01-08 00:00:00-05:00  355.271745  356.111868  352.013921  355.897186
#
#                               Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2021-01-04 00:00:00-05:00  110210800        0.0           0.0            0.0
# 2021-01-05 00:00:00-05:00   66426200        0.0           0.0            0.0
# 2021-01-06 00:00:00-05:00  107997700        0.0           0.0            0.0
# 2021-01-07 00:00:00-05:00   68766800        0.0           0.0            0.0
# 2021-01-08 00:00:00-05:00   71677200        0.0           0.0            0.0

# %%
print(spy_data.isna().any().any())
# Out:
# False
